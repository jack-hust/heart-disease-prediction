# %% [markdown]
# # **Heart Disease Prediction**

# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os
print(os.listdir())
# Out:
# ['.virtual_documents']

# %% [markdown]
# # **Importing Models**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # **Loading Dataset**

# %%
data = pd.read_csv("/kaggle/input/dataset-btl1/heart.csv")
data.shape #Rows and collumns
# Out:
# (1025, 14)

# %% [markdown]
# # **Checking for Missing data**

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # **Statistics for each column**

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# # **Find Correlation**

# %%
data["target"].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
data["target"].value_counts().plot( kind = "bar", color = ["salmon", "lightblue"]);

# %%
data.sex.value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
pd.crosstab(data.target, data.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
pd.crosstab(data.target, data.sex).plot(kind= "bar", figsize=(10,6), color= ["salmon", "lightblue"]);
plt.title("Heart Disease frequence for Sex")
plt.xlabel("0 = No Disease, 1 = Disease")
plt.ylabel("Heart Disease Positive")
plt.legend( ["Female", "Male"]);

# %%
data["target"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.scatter(data.age[data.target == 1],
           data.thalach[data.target == 1], 
           color="salmon")

plt.scatter(data.age[data.target == 0],
           data.thalach[data.target == 0], 
           color="blue");

plt.title("Max Heart Rate VS Age")
plt.xlabel("Age")
plt.ylabel("Max Heart Rate")
plt.legend(["Disease", "No Disease"])

# %%
# Make the crosstab more visual
pd.crosstab(data.cp, data.target).plot(kind="bar",
                                   figsize=(10, 6),
                                   color=["salmon", "lightblue"])

plt.title("Heart DIsease Frequency vs Chest Pain")
plt.xlabel("Chest Pain Type")
plt.ylabel("Heart Disease Postive")
plt.legend(["0", "1"])

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.132696 -0.390227  0.088163  0.208137 -0.169105  0.271551
# sex      -0.055117 -0.049365  0.139157  0.084687 -0.026666  0.111729
# cp        0.043581  0.306839 -0.401513 -0.174733  0.131633 -0.176206
# trestbps -0.123794 -0.039264  0.061197  0.187434 -0.120445  0.104554
# chol     -0.147410 -0.021772  0.067382  0.064880 -0.014248  0.074259
# fbs      -0.104051 -0.008866  0.049261  0.010859 -0.061902  0.137156
# restecg   1.000000  0.048411 -0.065606 -0.050114  0.086086 -0.078072
# thalach   0.048411  1.000000 -0.380281 -0.349796  0.395308 -0.207888
# exang    -0.065606 -0.380281  1.000000  0.310844 -0.267335  0.107849
# oldpeak  -0.050114 -0.349796  0.310844  1.000000 -0.575189  0.221816
# slope     0.086086  0.395308 -0.267335 -0.575189  1.000000 -0.073440
# ca       -0.078072 -0.207888  0.107849  0.221816 -0.073440  1.000000
# thal     -0.020504 -0.098068  0.197201  0.202672 -0.094090  0.149014
# target    0.134468  0.422895 -0.438029 -0.438441  0.345512 -0.382085
#
#               thal    target
# age       0.072297 -0.229324
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.059276 -0.138772
# chol      0.100244 -0.099966
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.098068  0.422895
# exang     0.197201 -0.438029
# oldpeak   0.202672 -0.438441
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %% [markdown]
# # **Find Correlation**

# %%
corr_matrix = data.corr()
print(corr_matrix)
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.132696 -0.390227  0.088163  0.208137 -0.169105  0.271551
# sex      -0.055117 -0.049365  0.139157  0.084687 -0.026666  0.111729
# cp        0.043581  0.306839 -0.401513 -0.174733  0.131633 -0.176206
# trestbps -0.123794 -0.039264  0.061197  0.187434 -0.120445  0.104554
# chol     -0.147410 -0.021772  0.067382  0.064880 -0.014248  0.074259
# fbs      -0.104051 -0.008866  0.049261  0.010859 -0.061902  0.137156
# restecg   1.000000  0.048411 -0.065606 -0.050114  0.086086 -0.078072
# thalach   0.048411  1.000000 -0.380281 -0.349796  0.395308 -0.207888
# exang    -0.065606 -0.380281  1.000000  0.310844 -0.267335  0.107849
# oldpeak  -0.050114 -0.349796  0.310844  1.000000 -0.575189  0.221816
# slope     0.086086  0.395308 -0.267335 -0.575189  1.000000 -0.073440
# ca       -0.078072 -0.207888  0.107849  0.221816 -0.073440  1.000000
# thal     -0.020504 -0.098068  0.197201  0.202672 -0.094090  0.149014
# target    0.134468  0.422895 -0.438029 -0.438441  0.345512 -0.382085
#
#               thal    target
# age       0.072297 -0.229324
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.059276 -0.138772
# chol      0.100244 -0.099966
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.098068  0.422895
# exang     0.197201 -0.438029
# oldpeak   0.202672 -0.438441
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %%
corr_matrix = data.corr()
fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (14.5, -0.5)

# %%
data.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # **Checking Data Balance**

# %%
sns.set_style('whitegrid')
sns.countplot(x='target',data=data,palette='RdBu_r')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# # **Splitting into X and y**

# %%
feature_cols = ['cp','thalach','slope']
X = data[feature_cols]
y = data['target']

# %% [markdown]
# # **Classification Models**

# %% [markdown]
# **1. KNearest Neighbors Classification Model**

# %% [markdown]
# Finding the best value for K

# %%
from sklearn.model_selection import cross_val_score
knn_scores = []
for k in range(1,21):
    knn_classifier = KNeighborsClassifier(n_neighbors = k)
    score=cross_val_score(knn_classifier,X,y,cv=10)
    knn_scores.append(score.mean())
plt.plot([k for k in range(1, 21)], knn_scores, color = 'red')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('K Neighbors Classifier scores for different K values')
# Out:
# Text(0.5, 1.0, 'K Neighbors Classifier scores for different K values')

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
score=cross_val_score(knn_classifier,X,y,cv=10)
print(score.mean())
# Out:
# 0.7257471920807158

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8195121951219512

# %% [markdown]
# # **Testing**

# %%
test1 = (3,150,0)
test1 = np.asarray(test1)
test1 = test1.reshape(1,-1)
test1_predict = knn.predict(test1)
if test1_predict==1:
    print("Person has high chance of heart disease")
else:
    print("Person has low chance of heart disease")
# Out:
# Person has high chance of heart disease

# %%
test2 = (0,115,1)
test2 = np.asarray(test2)
test2 = test2.reshape(1,-1)
test2_predict = knn.predict(test2)
if test2_predict==1:
    print("Person has high chance of heart disease")
else:
    print("Person has low chance of heart disease")
# Out:
# Person has low chance of heart disease

# %% [markdown]
# # **Train Test split**

# %%
from sklearn.model_selection import train_test_split

predictors = data.drop("target",axis=1)
target = data["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (820, 13)

# %%
X_test.shape
# Out:
# (205, 13)

# %%
Y_train.shape
# Out:
# (820,)

# %%
Y_test.shape
# Out:
# (205,)

# %% [markdown]
# # **Model Fitting**

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (205,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 86.34 %

# %% [markdown]
# **Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (205,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.37 %

# %% [markdown]
# **SVM**

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (205,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 83.9 %

# %% [markdown]
# **K Nearest Neighbors**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (205,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 72.2 %

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (205,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 100.0 %

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (205,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 100.0 %

# %% [markdown]
# **XGBoost**

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (205,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 100.0 %

# %% [markdown]
# **Neural Network**

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# https://stats.stackexchange.com/a/136542 helped a lot in avoiding overfitting

model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 26/26 [==============================] - 1s 2ms/step - loss: 18.7666 - accuracy: 0.4951
# Epoch 2/300
# 26/26 [==============================] - 0s 2ms/step - loss: 7.7277 - accuracy: 0.4439
# Epoch 3/300
# 26/26 [==============================] - 0s 2ms/step - loss: 6.8818 - accuracy: 0.4232
# Epoch 4/300
# 26/26 [==============================] - 0s 2ms/step - loss: 6.3675 - accuracy: 0.4451
# Epoch 5/300
# 26/26 [==============================] - 0s 2ms/step - loss: 5.9824 - accuracy: 0.4341
# Epoch 6/300
# 26/26 [==============================] - 0s 2ms/step - loss: 5.5653 - accuracy: 0.4390
# Epoch 7/300
# 26/26 [==============================] - 0s 2ms/step - loss: 5.1197 - accuracy: 0.4488
# Epoch 8/300
# 26/26 [==============================] - 0s 2ms/step - loss: 4.6527 - accuracy: 0.4512
# Epoch 9/300
# 26/26 [==============================] - 0s 2ms/step - loss: 4.1716 - accuracy: 0.4598
# Epoch 10/300
# 26/26 [==============================] - 0s 2ms/step - loss: 3.6129 - accuracy: 0.4634
# Epoch 11/300
# 26/26 [==============================] - 0s 2ms/step - loss: 2.8974 - accuracy: 0.4683
# Epoch 12/300
# 26/26 [==============================] - 0s 2ms/step - loss: 2.1085 - accuracy: 0.5037
# Epoch 13/300
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6420 - accuracy: 0.4988
# Epoch 14/300
# 26/26 [==============================] - 0s 2ms/step - loss: 1.3049 - accuracy: 0.5524
# Epoch 15/300
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0441 - accuracy: 0.5805
# Epoch 16/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9424 - accuracy: 0.6110
# Epoch 17/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8528 - accuracy: 0.6268
# Epoch 18/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7435 - accuracy: 0.6476
# Epoch 19/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6601 - accuracy: 0.6841
# Epoch 20/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6201 - accuracy: 0.6866
# Epoch 21/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6222 - accuracy: 0.7085
# Epoch 22/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5658 - accuracy: 0.7134
# Epoch 23/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5420 - accuracy: 0.7329
# Epoch 24/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.7378
# Epoch 25/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5169 - accuracy: 0.7439
# Epoch 26/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5152 - accuracy: 0.7439
# Epoch 27/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7439
# Epoch 28/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7622
# Epoch 29/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.7585
# Epoch 30/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.7537
# Epoch 31/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4752 - accuracy: 0.7634
# Epoch 32/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4637 - accuracy: 0.7695
# Epoch 33/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4532 - accuracy: 0.7805
# Epoch 34/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4404 - accuracy: 0.7927
# Epoch 35/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.7817
# Epoch 36/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.7902
# Epoch 37/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.7963
# Epoch 38/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4253 - accuracy: 0.7902
# Epoch 39/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.7927
# Epoch 40/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.7988
# Epoch 41/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4150 - accuracy: 0.8049
# Epoch 42/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8000
# Epoch 43/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.7902
# Epoch 44/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4082 - accuracy: 0.8085
# Epoch 45/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4070 - accuracy: 0.8098
# Epoch 46/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4208 - accuracy: 0.7890
# Epoch 47/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7939
# Epoch 48/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8183
# Epoch 49/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8280
# Epoch 50/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4412 - accuracy: 0.7963
# Epoch 51/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4251 - accuracy: 0.7988
# Epoch 52/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.8220
# Epoch 53/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8122
# Epoch 54/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.8000
# Epoch 55/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.8085
# Epoch 56/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8232
# Epoch 57/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8280
# Epoch 58/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8171
# Epoch 59/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3935 - accuracy: 0.8232
# Epoch 60/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3904 - accuracy: 0.8244
# Epoch 61/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8195
# Epoch 62/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8183
# Epoch 63/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8037
# Epoch 64/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8378
# Epoch 65/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8122
# Epoch 66/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3911 - accuracy: 0.8329
# Epoch 67/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8305
# Epoch 68/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8366
# Epoch 69/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3873 - accuracy: 0.8341
# Epoch 70/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4026 - accuracy: 0.8207
# Epoch 71/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3881 - accuracy: 0.8305
# Epoch 72/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.8305
# Epoch 73/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8341
# Epoch 74/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8195
# Epoch 75/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8317
# Epoch 76/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4249 - accuracy: 0.7951
# Epoch 77/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8366
# Epoch 78/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3879 - accuracy: 0.8402
# Epoch 79/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3855 - accuracy: 0.8354
# Epoch 80/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3879 - accuracy: 0.8268
# Epoch 81/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.8354
# Epoch 82/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8256
# Epoch 83/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8317
# Epoch 84/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8049
# Epoch 85/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8451
# Epoch 86/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8427
# Epoch 87/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.8220
# Epoch 88/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8354
# Epoch 89/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3857 - accuracy: 0.8378
# Epoch 90/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8415
# Epoch 91/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8415
# Epoch 92/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3859 - accuracy: 0.8366
# Epoch 93/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3819 - accuracy: 0.8317
# Epoch 94/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8378
# Epoch 95/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8244
# Epoch 96/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.8171
# Epoch 97/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8427
# Epoch 98/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3763 - accuracy: 0.8512
# Epoch 99/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3901 - accuracy: 0.8476
# Epoch 100/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8354
# Epoch 101/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8171
# Epoch 102/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4114 - accuracy: 0.8146
# Epoch 103/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3955 - accuracy: 0.8293
# Epoch 104/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8354
# Epoch 105/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8439
# Epoch 106/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3756 - accuracy: 0.8439
# Epoch 107/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.8427
# Epoch 108/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8402
# Epoch 109/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8244
# Epoch 110/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8268
# Epoch 111/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8256
# Epoch 112/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4266 - accuracy: 0.8012
# Epoch 113/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4305 - accuracy: 0.8073
# Epoch 114/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8354
# Epoch 115/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8293
# Epoch 116/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8244
# Epoch 117/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4311 - accuracy: 0.7988
# Epoch 118/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8220
# Epoch 119/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8220
# Epoch 120/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8354
# Epoch 121/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.8439
# Epoch 122/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8366
# Epoch 123/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3785 - accuracy: 0.8415
# Epoch 124/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8354
# Epoch 125/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.8305
# Epoch 126/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8390
# Epoch 127/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8390
# Epoch 128/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8378
# Epoch 129/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8329
# Epoch 130/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8390
# Epoch 131/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3803 - accuracy: 0.8402
# Epoch 132/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3739 - accuracy: 0.8476
# Epoch 133/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8366
# Epoch 134/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3840 - accuracy: 0.8366
# Epoch 135/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8463
# Epoch 136/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8256
# Epoch 137/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8159
# Epoch 138/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8280
# Epoch 139/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.8488
# Epoch 140/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8329
# Epoch 141/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8280
# Epoch 142/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8500
# Epoch 143/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8439
# Epoch 144/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.8256
# Epoch 145/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8451
# Epoch 146/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3893 - accuracy: 0.8402
# Epoch 147/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8402
# Epoch 148/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8439
# Epoch 149/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8463
# Epoch 150/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3851 - accuracy: 0.8317
# Epoch 151/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3857 - accuracy: 0.8463
# Epoch 152/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.8390
# Epoch 153/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.8390
# Epoch 154/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3825 - accuracy: 0.8488
# Epoch 155/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3784 - accuracy: 0.8354
# Epoch 156/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.8354
# Epoch 157/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8463
# Epoch 158/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3745 - accuracy: 0.8476
# Epoch 159/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8427
# Epoch 160/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3710 - accuracy: 0.8402
# Epoch 161/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8378
# Epoch 162/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3980 - accuracy: 0.8390
# Epoch 163/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3856 - accuracy: 0.8378
# Epoch 164/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8646
# Epoch 165/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8439
# Epoch 166/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3721 - accuracy: 0.8573
# Epoch 167/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8415
# Epoch 168/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8329
# Epoch 169/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8415
# Epoch 170/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8329
# Epoch 171/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8463
# Epoch 172/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8305
# Epoch 173/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.8134
# Epoch 174/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3771 - accuracy: 0.8451
# Epoch 175/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3705 - accuracy: 0.8524
# Epoch 176/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.8427
# Epoch 177/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3807 - accuracy: 0.8354
# Epoch 178/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3804 - accuracy: 0.8378
# Epoch 179/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3719 - accuracy: 0.8427
# Epoch 180/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3840 - accuracy: 0.8293
# Epoch 181/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8366
# Epoch 182/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8317
# Epoch 183/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4186 - accuracy: 0.8098
# Epoch 184/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8317
# Epoch 185/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3779 - accuracy: 0.8500
# Epoch 186/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8451
# Epoch 187/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3852 - accuracy: 0.8220
# Epoch 188/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4208 - accuracy: 0.8098
# Epoch 189/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8329
# Epoch 190/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8366
# Epoch 191/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.8329
# Epoch 192/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8329
# Epoch 193/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8463
# Epoch 194/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3722 - accuracy: 0.8439
# Epoch 195/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8378
# Epoch 196/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8585
# Epoch 197/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8402
# Epoch 198/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3652 - accuracy: 0.8463
# Epoch 199/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3789 - accuracy: 0.8439
# Epoch 200/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3708 - accuracy: 0.8451
# Epoch 201/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3871 - accuracy: 0.8402
# Epoch 202/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8354
# Epoch 203/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8390
# Epoch 204/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.8415
# Epoch 205/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8378
# Epoch 206/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3743 - accuracy: 0.8524
# Epoch 207/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8415
# Epoch 208/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8378
# Epoch 209/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8439
# Epoch 210/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8439
# Epoch 211/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.8232
# Epoch 212/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8305
# Epoch 213/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8537
# Epoch 214/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8378
# Epoch 215/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4056 - accuracy: 0.8256
# Epoch 216/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3679 - accuracy: 0.8549
# Epoch 217/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8463
# Epoch 218/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3832 - accuracy: 0.8378
# Epoch 219/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8488
# Epoch 220/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8439
# Epoch 221/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3688 - accuracy: 0.8390
# Epoch 222/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8476
# Epoch 223/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3807 - accuracy: 0.8402
# Epoch 224/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8537
# Epoch 225/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3907 - accuracy: 0.8305
# Epoch 226/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8354
# Epoch 227/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8537
# Epoch 228/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3814 - accuracy: 0.8317
# Epoch 229/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8476
# Epoch 230/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8293
# Epoch 231/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3843 - accuracy: 0.8305
# Epoch 232/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.8439
# Epoch 233/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3692 - accuracy: 0.8524
# Epoch 234/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8451
# Epoch 235/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3756 - accuracy: 0.8378
# Epoch 236/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8183
# Epoch 237/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8402
# Epoch 238/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8402
# Epoch 239/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.8415
# Epoch 240/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3731 - accuracy: 0.8402
# Epoch 241/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8317
# Epoch 242/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.8415
# Epoch 243/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8415
# Epoch 244/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3824 - accuracy: 0.8415
# Epoch 245/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8244
# Epoch 246/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8402
# Epoch 247/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8354
# Epoch 248/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8244
# Epoch 249/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8463
# Epoch 250/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8524
# Epoch 251/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8500
# Epoch 252/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8561
# Epoch 253/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4094 - accuracy: 0.8268
# Epoch 254/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8512
# Epoch 255/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8427
# Epoch 256/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8049
# Epoch 257/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8305
# Epoch 258/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8427
# Epoch 259/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8159
# Epoch 260/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8341
# Epoch 261/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3740 - accuracy: 0.8354
# Epoch 262/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8415
# Epoch 263/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8512
# Epoch 264/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8463
# Epoch 265/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3710 - accuracy: 0.8402
# Epoch 266/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8390
# Epoch 267/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.8390
# Epoch 268/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.8402
# Epoch 269/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8537
# Epoch 270/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8585
# Epoch 271/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.8366
# Epoch 272/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8256
# Epoch 273/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8402
# Epoch 274/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8329
# Epoch 275/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8293
# Epoch 276/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8280
# Epoch 277/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3701 - accuracy: 0.8537
# Epoch 278/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3816 - accuracy: 0.8354
# Epoch 279/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8585
# Epoch 280/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.8488
# Epoch 281/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8378
# Epoch 282/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8415
# Epoch 283/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8354
# Epoch 284/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3756 - accuracy: 0.8366
# Epoch 285/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8415
# Epoch 286/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8366
# Epoch 287/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.8305
# Epoch 288/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.8366
# Epoch 289/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8378
# Epoch 290/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8354
# Epoch 291/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8329
# Epoch 292/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8317
# Epoch 293/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8366
# Epoch 294/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3749 - accuracy: 0.8427
# Epoch 295/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.8220
# Epoch 296/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3910 - accuracy: 0.8317
# Epoch 297/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3814 - accuracy: 0.8415
# Epoch 298/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8366
# Epoch 299/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8232
# Epoch 300/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.8476

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
Y_pred_nn.shape
# Out:
# (205, 1)

# %%
rounded = [round(x) for x in Y_pred_nn]
Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")

#Note: Accuracy of 85% can be achieved on the test set, by setting epochs=2000, and number of nodes = 11.
# Out:
# The accuracy score achieved using Neural Network is: 85.85 %

# %% [markdown]
# **Output final score**

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 86.34 %
# The accuracy score achieved using Naive Bayes is: 85.37 %
# The accuracy score achieved using Support Vector Machine is: 83.9 %
# The accuracy score achieved using K-Nearest Neighbors is: 72.2 %
# The accuracy score achieved using Decision Tree is: 100.0 %
# The accuracy score achieved using Random Forest is: 100.0 %
# The accuracy score achieved using XGBoost is: 100.0 %
# The accuracy score achieved using Neural Network is: 85.85 %

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Your data
scores = [score_lr, score_nb, score_svm, score_knn, score_dt, score_rf, score_xgb, score_nn]
algorithms = ["Logistic Regression", "Naive Bayes", "Support Vector Machine", "K-Nearest Neighbors", "Decision Tree", "Random Forest", "XGBoost", "Neural Network"]

# Create a DataFrame
data = {'Algorithms': algorithms, 'Accuracy Score': scores}
df = pd.DataFrame(data)

# Set the figure size
sns.set(rc={'figure.figsize':(15, 8)})

# Create the bar plot
sns.barplot(x='Algorithms', y='Accuracy Score', data=df)

# Set labels
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

# Show the plot
plt.show()
